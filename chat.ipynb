# %%
import pandas as pd

# %%
MyData = pd.read_excel('chat_modified.xlsx')

# %%
MyData.head()
# Out:
#            date         time              name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  â€Ž[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  â€Ž[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                          message Unnamed: 4 Unnamed: 5  \
# 0                        Key window Dagara petta        NaN        NaN
# 1           ANNAMACHARYA.rar Ÿ??document omitted        NaN        NaN
# 2   pick and place robot.rar Ÿ??document omitted        NaN        NaN
# 3               Kshtriya complete chesi pettandi        NaN        NaN
# 4                 After ugadi vastharu pillaging        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# ...

# %%
MyData.columns
# Out:
# Index(['date', 'time', 'name', 'message', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
col=['Unnamed: 4', 'Unnamed: 5',
       'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'Unnamed: 12']

# %%
MyData.drop(col,axis=1,inplace=True)

# %%
MyData.head()
# Out:
#            date         time              name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  â€Ž[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  â€Ž[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                          message
# 0                        Key window Dagara petta
# 1           ANNAMACHARYA.rar Ÿ??document omitted
# 2   pick and place robot.rar Ÿ??document omitted
# 3               Kshtriya complete chesi pettandi
# 4                 After ugadi vastharu pillaging

# %%
MyData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8134 entries, 0 to 8133
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     7907 non-null   object
#  1   time     7388 non-null   object
#  2   name     7348 non-null   object
#  3   message  7329 non-null   object
# dtypes: object(4)
# memory usage: 254.3+ KB

# %%
MyData = MyData.dropna()

# %%
MyData.shape
# Out:
# (7329, 4)

# %%
MyData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7329 entries, 0 to 8133
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     7329 non-null   object
#  1   time     7329 non-null   object
#  2   name     7329 non-null   object
#  3   message  7329 non-null   object
# dtypes: object(4)
# memory usage: 286.3+ KB

# %%
MyData.head()
# Out:
#            date         time              name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  â€Ž[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  â€Ž[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                          message
# 0                        Key window Dagara petta
# 1           ANNAMACHARYA.rar Ÿ??document omitted
# 2   pick and place robot.rar Ÿ??document omitted
# 3               Kshtriya complete chesi pettandi
# 4                 After ugadi vastharu pillaging

# %%
MyData.tail()
# Out:
#               date          time   name  \
# 8129  â€Ž[19/09/21   11:12:48 AM   Anil
# 8130  â€Ž[19/09/21    4:10:47 PM   Anil
# 8131  â€Ž[19/09/21    4:19:32 PM   Anil
# 8132     [20/09/21    9:05:22 PM   Anil
# 8133     [21/09/21    9:37:38 PM   Anil
#
#                                               message
# 8129                                       abhi to me
# 8130                                 Ÿ??image omitted
# 8131   amount to  be recived.xlsx Ÿ??document omitted
# 8132                 Sheets update chesi send chyandi
# 8133                                      Emyindi ra?

# %%
 MyData.nunique()
# Out:
# date        679
# time       6588
# name         17
# message    5579
# dtype: int64

# %%
members= [' ABHINAY GOUD', ' Tss Shivasenkar', ' Shekar Tss', ' Anil']

# %%
newdata=MyData[((MyData['name']==' ABHINAY GOUD')|(MyData['name']==' Tss Shivasenkar')|(MyData['name']==' Anil')|(MyData['name'] ==' Shekar Tss'))]

# %%
newdata.head(10)
# Out:
#            date         time              name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  â€Ž[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  â€Ž[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
# 5     [21/03/20   6:41:36 PM      ABHINAY GOUD
# 6     [21/03/20   7:03:15 PM        Shekar Tss
# 7     [21/03/20   7:25:12 PM              Anil
# 8     [21/03/20   7:33:17 PM              Anil
# 9  â€Ž[21/03/20   7:37:26 PM   Tss Shivasenkar
#
#                                             message
# 0                           Key window Dagara petta
# 1              ANNAMACHARYA.rar Ÿ??document omitted
# 2      pick and place robot.rar Ÿ??document omitted
# 3                  Kshtriya complete chesi pettandi
# 4                    After ugadi vastharu pillaging
# 5                      Kshtriya valaku doc evvaleda
# 6                                     @919705192524
# ...

# %%
newdata.tail(10)
# Out:
#               date          time   name  \
# 8124     [07/09/21    8:55:38 PM   Anil
# 8125  â€Ž[14/09/21   10:22:31 AM   Anil
# 8126  â€Ž[14/09/21   10:25:59 AM   Anil
# 8127  â€Ž[19/09/21   11:10:06 AM   Anil
# 8128     [19/09/21   11:10:11 AM   Anil
# 8129  â€Ž[19/09/21   11:12:48 AM   Anil
# 8130  â€Ž[19/09/21    4:10:47 PM   Anil
# 8131  â€Ž[19/09/21    4:19:32 PM   Anil
# 8132     [20/09/21    9:05:22 PM   Anil
# 8133     [21/09/21    9:37:38 PM   Anil
#
#                                                 message
# 8124                                   Yapudu last exam
# 8125                                   Ÿ??image omitted
# 8126   ALL CONSCIENCE COLLEGES.xlsx Ÿ??document omitted
# 8127   Accounts halten 2018-21.xlsx Ÿ??document omitted
# 8128                                               1801
# 8129                                         abhi to me
# 8130                                   Ÿ??image omitted
# 8131     amount to  be recived.xlsx Ÿ??document omitted
# ...

# %% [markdown]
# ## TOTAL COUNT

# %%
newdata['name'].value_counts()
# Out:
#  Tss Shivasenkar    2300
#  Shekar Tss         2102
#  ABHINAY GOUD       1797
#  Anil               1106
# Name: name, dtype: int64

# %%
newdata.head()
# Out:
#            date         time              name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  â€Ž[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  â€Ž[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                          message
# 0                        Key window Dagara petta
# 1           ANNAMACHARYA.rar Ÿ??document omitted
# 2   pick and place robot.rar Ÿ??document omitted
# 3               Kshtriya complete chesi pettandi
# 4                 After ugadi vastharu pillaging

# %%
my_msgs = newdata[(newdata.name==' Tss Shivasenkar')]

# %% [markdown]
# ## MY MESSAGES

# %%
my_msgs
# Out:
#               date         time              name  \
# 1     â€Ž[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2     â€Ž[21/03/20   3:38:27 PM   Tss Shivasenkar
# 9     â€Ž[21/03/20   7:37:26 PM   Tss Shivasenkar
# 11       [21/03/20   7:39:12 PM   Tss Shivasenkar
# 14    â€Ž[22/03/20   1:55:25 PM   Tss Shivasenkar
# ...            ...          ...               ...
# 8052     [27/07/21   2:51:16 PM   Tss Shivasenkar
# 8053     [27/07/21   2:51:33 PM   Tss Shivasenkar
# 8096     [23/08/21   6:28:13 PM   Tss Shivasenkar
# 8097     [23/08/21   6:28:21 PM   Tss Shivasenkar
# 8104     [26/08/21   8:39:15 PM   Tss Shivasenkar
#
#                                             message
# 1              ANNAMACHARYA.rar Ÿ??document omitted
# 2      pick and place robot.rar Ÿ??document omitted
# 9                                  Ÿ??image omitted
# 11                    Vallu clg ki vellaledhu antaa
# 14                          Ÿ??Contact card omitted
# ...
